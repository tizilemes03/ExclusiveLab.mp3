# %%
from gapminder import gapminder
import seaborn . objects as so

# %%
#punto a)
datosArgentina = gapminder[gapminder["country"].isin(["Argentina"])]
#datosArgentina
(so.Plot(data = datosArgentina, x = "year", y = "lifeExp" ).add(so.Dots()))

# %%
#punto b)
datosAmerica = gapminder[gapminder["continent"]==("Americas")]
(Invalid RGBA argument: 'country'

Invalid RGBA argument: 'country'


    so.Plot(
        data = datosAmerica, 
        x = "year" , 
        y = "lifeExp")
    .add( 
        so.Line(), color ="country"  
        )
    .add(
        so.Dots(color = "red"))
)

# %%
#punto c
